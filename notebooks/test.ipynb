# %%
import sys, os
sys.path.insert(0, os.path.abspath(os.path.join(os.getcwd(), '..')))

from utils.db_connection import run_query

df = run_query("SELECT * FROM all_players LIMIT 5")
print(df.columns.tolist())
print(df.head())
# Out:
# ['Team ID', 'Team Name', 'Player ID', 'Player Name', 'Role', 'Batting Style', 'Bowling Style']
#    Team ID Team Name Player ID       Player Name     Role   Batting Style  \
# 0        2     India     11808      Shubman Gill  BATSMEN  Right-hand bat
# 1        2     India     13940  Yashasvi Jaiswal  BATSMEN   Left-hand bat
# 2        2     India     13866     Sai Sudharsan  BATSMEN   Left-hand bat
# 3        2     India       576      Rohit Sharma  BATSMEN  Right-hand bat
# 4        2     India      1413       Virat Kohli  BATSMEN  Right-hand bat
#
#         Bowling Style
# 0  Right-arm offbreak
# 1  Right-arm legbreak
# 2  Right-arm legbreak
# 3  Right-arm offbreak
# 4    Right-arm medium
